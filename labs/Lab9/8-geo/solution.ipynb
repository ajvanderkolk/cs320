# %% [markdown]
# # Background
#
# ## Goal
#
# Say you want to advertise to nearby residents for this grocery store: https://freshmadisonmarket.com/.  You want to create a map like this to identify these potential customers:

# %%
from IPython.display import Image
Image(filename='expected.png')

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
plt.rcParams["font.size"] = 16

# %%
# %matplotlib inline

# %%
city = gpd.read_file("zip://city.zip")
lakes = gpd.read_file("zip://lakes.zip")
street = gpd.read_file("zip://street.zip")

# %%
# BUG 1: why isn't it finding the one on the corner of University and N Lake Street?
fresh = gpd.tools.geocode("Fresh Madison Market; Madison, WI")
fresh
# Out:
#                      geometry  \
# 0  POINT (-77.64875 38.81934)
#
#                                              address
# 0  James Madison Marketplace, Virginia, United St...

# %%
def plot_background():
    ax = city.plot(color="lightgray", alpha=.2, figsize=(12, 12), zorder=2)
    lakes.plot(color="lightblue", ax=ax, zorder=1, alpha=0.8)
    street.plot(color="darkgray", alpha = .5, ax=ax, zorder=3)
    ax.set_axis_off()
    return ax

# %%
# BUG 2: why is it complaining we didn't do to_crs, when we did?
fresh = fresh.to_crs("epsg:32616") # reproject to meters
fresh.geometry = fresh.geometry.buffer(2000)
fresh = fresh.to_crs(city.crs) # reproject back to lat, lon for plotting

# %%
# BUG 3: why isn't it only highlighting land near the grocery store?
ax = plot_background()
fresh.intersection(city.unary_union).plot(color="#ffbfba", ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 # BUG 3: why isn't it only highlighting land near the grocery store?
#       2 ax = plot_background()
# ----> 3 fresh.intersection(city.unary_union).plot(color="#ffbfba", ax=ax)
#
# File /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:876, in GeoSeries.plot(self, *args, **kwargs)
#     874 @doc(plot_series)
#     875 def plot(self, *args, **kwargs):
# --> 876     return plot_series(self, *args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/geopandas/plotting.py:403, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     401     bounds = s.total_bounds
#     402     y_coord = np.mean([bounds[1], bounds[3]])
# --> 403     ax.set_aspect(1 / np.cos(y_coord * np.pi / 180))
#     404     # formula ported from R package sp
#     405     # https://github.com/edzer/sp/blob/master/R/mapasp.R
#     406 else:
#     407     ax.set_aspect("equal")
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:1666, in _AxesBase.set_aspect(self, aspect, adjustable, anchor, share)
#    1664     aspect = float(aspect)  # raise ValueError if necessary
#    1665     if aspect <= 0 or not np.isfinite(aspect):
# -> 1666         raise ValueError("aspect must be finite and positive ")
#    1668 if share:
#    1669     axes = {sibling for name in self._axis_names
#    1670             for sibling in self._shared_axes[name].get_siblings(self)}
#
# ValueError: aspect must be finite and positive
